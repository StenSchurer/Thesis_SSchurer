# %% [markdown]
# # Plotting the LSPIV data for different parameter settings
#
# Sten Schurer

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import re
from tabulate import tabulate
from mpl_toolkits.axes_grid1 import make_axes_locatable, axes_size

# %% [markdown]
# ### Editing

# %%
fig, axs = plt.subplots(2, 2, figsize=(13, 7))
BackG_AR = plt.imread(r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/Report/Images/Background_LSPIV_40Transparent.JPG')
BackG_BR = plt.imread(r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/Report/Images/Background_before_rain.JPG')
BackG_TR = plt.imread(r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/Report/Images/Background_tracers.JPG')

pth1   = r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/LSPIV/Edited/After rain/OS/'
Data1   = pd.DataFrame(np.loadtxt(os.path.join(pth1, 'average.txt')))
Data1.columns = ['X', 'Y', 'u_avg', 'v_avg', 'mask_avg']
color=np.sqrt(Data1['v_avg']**2 + Data1['u_avg']**2)

axs[0, 0].quiver(Data1['X'], Data1['Y'], Data1['u_avg'], Data1['v_avg'], color='k', width=0.0041)
im = axs[0, 0].quiver(Data1['X'], Data1['Y'], Data1['u_avg'], Data1['v_avg'], color, width=0.004)
axs[0, 0].imshow(BackG_AR, extent=[0, 130, 0, 70])
axs[0, 0].set_title('OS', fontsize=15)

pth2  = r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/LSPIV/Edited/After rain/OSG/'
Data2   = pd.DataFrame(np.loadtxt(os.path.join(pth2, 'average.txt')))
Data2.columns = ['X', 'Y', 'u_avg', 'v_avg', 'mask_avg']
color=np.sqrt(Data2['v_avg']**2 + Data2['u_avg']**2)

axs[0, 1].quiver(Data2['X'], Data2['Y'], Data2['u_avg'], Data2['v_avg'], color='k', width=0.0041)
axs[0, 1].quiver(Data2['X'], Data2['Y'], Data2['u_avg'], Data2['v_avg'], color, width=0.004)
axs[0, 1].imshow(BackG_AR, extent=[0, 130, 0, 70])
axs[0, 1].set_title('OSG', fontsize=15)

pth3  = r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/LSPIV/Edited/After rain/OSGG/'
Data3   = pd.DataFrame(np.loadtxt(os.path.join(pth3, 'average.txt')))
Data3.columns = ['X', 'Y', 'u_avg', 'v_avg', 'mask_avg']
color=np.sqrt(Data3['v_avg']**2 + Data3['u_avg']**2)

axs[1, 0].quiver(Data3['X'], Data3['Y'], Data3['u_avg'], Data3['v_avg'], color='k', width=0.0041)
axs[1, 0].quiver(Data3['X'], Data3['Y'], Data3['u_avg'], Data3['v_avg'], color, width=0.004)
axs[1, 0].imshow(BackG_AR, extent=[0, 130, 0, 70])
axs[1, 0].set_title('OSGG', fontsize=15)

pth4  = r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/LSPIV/Edited/After rain/OSGGC/'
Data4   = pd.DataFrame(np.loadtxt(os.path.join(pth4, 'average.txt')))
Data4.columns = ['X', 'Y', 'u_avg', 'v_avg', 'mask_avg']
color=np.sqrt(Data4['v_avg']**2 + Data4['u_avg']**2)

axs[1, 1].quiver(Data4['X'], Data4['Y'], Data4['u_avg'], Data4['v_avg'], color='k', width=0.0041)
axs[1, 1].quiver(Data4['X'], Data4['Y'], Data4['u_avg'], Data4['v_avg'], color, width=0.004)
axs[1, 1].imshow(BackG_AR, extent=[0, 130, 0, 70])
axs[1, 1].set_title('OSGGC', fontsize=15)

for ax in axs.flat:
    ax.set_xlabel('Width [m]', fontsize=13)
    ax.set_ylabel('Lenght [m]', fontsize=13)

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()

fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.02, 0.7])
fig.colorbar(im, cax=cbar_ax, label='m/s')

cbar = fig.colorbar(im, cax=cbar_ax, label='m/s')
cbar.set_label('[m/s]',size=13)

# plt.savefig('C:/Users/SSchurer/Documents/TU_Delft/Thesis/LSPIV/Results/Vector_fields/Editing.jpg')

# %% [markdown]
# ### Length

# %%
fig, axs = plt.subplots(2, 2, figsize=(13, 7))
BackG_AR = plt.imread(r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/Report/Images/Background_LSPIV_40Transparent.JPG')
BackG_BR = plt.imread(r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/Report/Images/Background_before_rain.JPG')
BackG_TR = plt.imread(r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/Report/Images/Background_tracers.JPG')

pth1   = r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/LSPIV/Edited/After rain/OSGGC/'
Data1   = pd.DataFrame(np.loadtxt(os.path.join(pth1, 'average.txt')))
Data1.columns = ['X', 'Y', 'u_avg', 'v_avg', 'mask_avg']
color=np.sqrt(Data1['v_avg']**2 + Data1['u_avg']**2)

axs[0, 0].quiver(Data1['X'], Data1['Y'], Data1['u_avg'], Data1['v_avg'], color='k', width=0.0041)
im = axs[0, 0].quiver(Data1['X'], Data1['Y'], Data1['u_avg'], Data1['v_avg'], color, width=0.004)
axs[0, 0].imshow(BackG_AR, extent=[0, 130, 0, 70])
axs[0, 0].set_title('5', fontsize=15)

pth2  = r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/LSPIV/Edited/After rain/OSGGC_10/'
Data2   = pd.DataFrame(np.loadtxt(os.path.join(pth2, 'average.txt')))
Data2.columns = ['X', 'Y', 'u_avg', 'v_avg', 'mask_avg']
color=np.sqrt(Data2['v_avg']**2 + Data2['u_avg']**2)

axs[0, 1].quiver(Data2['X'], Data2['Y'], Data2['u_avg'], Data2['v_avg'], color='k', width=0.0041)
axs[0, 1].quiver(Data2['X'], Data2['Y'], Data2['u_avg'], Data2['v_avg'], color, width=0.004)
axs[0, 1].imshow(BackG_AR, extent=[0, 130, 0, 70])
axs[0, 1].set_title('10', fontsize=15)

pth3  = r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/LSPIV/Edited/After rain/OSGGC_15/'
Data3   = pd.DataFrame(np.loadtxt(os.path.join(pth3, 'average.txt')))
Data3.columns = ['X', 'Y', 'u_avg', 'v_avg', 'mask_avg']
color=np.sqrt(Data3['v_avg']**2 + Data3['u_avg']**2)

axs[1, 0].quiver(Data3['X'], Data3['Y'], Data3['u_avg'], Data3['v_avg'], color='k', width=0.0041)
axs[1, 0].quiver(Data3['X'], Data3['Y'], Data3['u_avg'], Data3['v_avg'], color, width=0.004)
axs[1, 0].imshow(BackG_AR, extent=[0, 130, 0, 70])
axs[1, 0].set_title('15', fontsize=15)

pth4  = r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/LSPIV/Edited/After rain/OSGGC_20/'
Data4   = pd.DataFrame(np.loadtxt(os.path.join(pth4, 'average.txt')))
Data4.columns = ['X', 'Y', 'u_avg', 'v_avg', 'mask_avg']
color=np.sqrt(Data4['v_avg']**2 + Data4['u_avg']**2)

axs[1, 1].quiver(Data4['X'], Data4['Y'], Data4['u_avg'], Data4['v_avg'], color='k', width=0.0041)
axs[1, 1].quiver(Data4['X'], Data4['Y'], Data4['u_avg'], Data4['v_avg'], color, width=0.004)
axs[1, 1].imshow(BackG_AR, extent=[0, 130, 0, 70])
axs[1, 1].set_title('20', fontsize=15)

for ax in axs.flat:
    ax.set_xlabel('Width [m]', fontsize=13)
    ax.set_ylabel('Lenght [m]', fontsize=13)

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()

fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.02, 0.7])
fig.colorbar(im, cax=cbar_ax, label='m/s')

cbar = fig.colorbar(im, cax=cbar_ax, label='m/s')
cbar.set_label('[m/s]',size=13)

# plt.savefig('C:/Users/SSchurer/Documents/TU_Delft/Thesis/LSPIV/Results/Vector_fields/Length.jpg')

# %% [markdown]
# ### Window size

# %%
fig, axs = plt.subplots(2, 2, figsize=(13, 7))
BackG_AR = plt.imread(r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/Report/Images/Background_LSPIV_40Transparent.JPG')
BackG_BR = plt.imread(r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/Report/Images/Background_before_rain.JPG')
BackG_TR = plt.imread(r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/Report/Images/Background_tracers.JPG')

pth1   = r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/LSPIV/Edited/After rain/OSGGC_W50/'
Data1   = pd.DataFrame(np.loadtxt(os.path.join(pth1, 'average.txt')))
Data1.columns = ['X', 'Y', 'u_avg', 'v_avg', 'mask_avg']
color=np.sqrt(Data1['v_avg']**2 + Data1['u_avg']**2)

axs[0, 0].quiver(Data1['X'], Data1['Y'], Data1['u_avg'], Data1['v_avg'], color='k', width=0.0041)
im = axs[0, 0].quiver(Data1['X'], Data1['Y'], Data1['u_avg'], Data1['v_avg'], color, width=0.004)
axs[0, 0].imshow(BackG_AR, extent=[0, 130, 0, 70])
axs[0, 0].set_title('50/25', fontsize=15)

pth2  = r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/LSPIV/Edited/After rain/OSGGC_10/'
Data2   = pd.DataFrame(np.loadtxt(os.path.join(pth2, 'average.txt')))
Data2.columns = ['X', 'Y', 'u_avg', 'v_avg', 'mask_avg']
color=np.sqrt(Data2['v_avg']**2 + Data2['u_avg']**2)

axs[0, 1].quiver(Data2['X'], Data2['Y'], Data2['u_avg'], Data2['v_avg'], color='k', width=0.0041)
axs[0, 1].quiver(Data2['X'], Data2['Y'], Data2['u_avg'], Data2['v_avg'], color, width=0.004)
axs[0, 1].imshow(BackG_AR, extent=[0, 130, 0, 70])
axs[0, 1].set_title('100/50', fontsize=15)

pth3  = r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/LSPIV/Edited/After rain/OSGGC_W100/'
Data3   = pd.DataFrame(np.loadtxt(os.path.join(pth3, 'average.txt')))
Data3.columns = ['X', 'Y', 'u_avg', 'v_avg', 'mask_avg']
color=np.sqrt(Data3['v_avg']**2 + Data3['u_avg']**2)

axs[1, 0].quiver(Data3['X'], Data3['Y'], Data3['u_avg'], Data3['v_avg'], color='k', width=0.0041)
axs[1, 0].quiver(Data3['X'], Data3['Y'], Data3['u_avg'], Data3['v_avg'], color, width=0.004)
axs[1, 0].imshow(BackG_AR, extent=[0, 130, 0, 70])
axs[1, 0].set_title('100/75', fontsize=15)

pth4  = r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/LSPIV/Edited/After rain/OSGGC_W200/'
Data4   = pd.DataFrame(np.loadtxt(os.path.join(pth4, 'average.txt')))
Data4.columns = ['X', 'Y', 'u_avg', 'v_avg', 'mask_avg']
color=np.sqrt(Data4['v_avg']**2 + Data4['u_avg']**2)

axs[1, 1].quiver(Data4['X'], Data4['Y'], Data4['u_avg'], Data4['v_avg'], color='k', width=0.0041)
axs[1, 1].quiver(Data4['X'], Data4['Y'], Data4['u_avg'], Data4['v_avg'], color, width=0.004)
axs[1, 1].imshow(BackG_AR, extent=[0, 130, 0, 70])
axs[1, 1].set_title('200/100', fontsize=15)

for ax in axs.flat:
    ax.set_xlabel('Width [m]', fontsize=13)
    ax.set_ylabel('Lenght [m]', fontsize=13)

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()

fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.02, 0.7])
fig.colorbar(im, cax=cbar_ax, label='m/s')

cbar = fig.colorbar(im, cax=cbar_ax, label='m/s')
cbar.set_label('[m/s]',size=13)

# plt.savefig('C:/Users/SSchurer/Documents/TU_Delft/Thesis/LSPIV/Results/Vector_fields/Window_size.jpg')

# %% [markdown]
# ### Single images

# %%
BackG_AR = plt.imread(r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/Report/Images/Background_LSPIV_40Transparent.JPG')
BackG_BR = plt.imread(r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/Report/Images/Background_before_rain.JPG')
BackG_TR = plt.imread(r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/Report/Images/Background_tracers.JPG')
BackG_NO = plt.imread(r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/Report/Images/Background_none.JPG')

pth1   = r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/LSPIV/Edited/After rain/OSGGC/'
Data1   = pd.DataFrame(np.loadtxt(os.path.join(pth1, 'average.txt')))
Data1.columns = ['X', 'Y', 'u_avg', 'v_avg', 'mask_avg']
color=np.sqrt(Data1['v_avg']**2 + Data1['u_avg']**2)

plt.quiver(Data1['X'], Data1['Y'], Data1['u_avg'], Data1['v_avg'], color='k', width=0.0041)
im = plt.quiver(Data1['X'], Data1['Y'], Data1['u_avg'], Data1['v_avg'], color, width=0.004)
plt.imshow(BackG_AR, extent=[0, 130, 0, 70])
plt.title('OSGGC', fontsize=15)
plt.xlabel('[m/s]',size=13)
plt.ylabel('[m/s]',size=13)

plt.colorbar(im, fraction=0.025, pad=0.03, label='m/s')

# plt.savefig('C:/Users/SSchurer/Documents/TU_Delft/Thesis/LSPIV/Results/Vector_fields/OSGGC.jpg')

# %% [markdown]
# ### Combine figures

# %% [raw]
# BackG_AR = plt.imread(r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/Report/Images/Background_LSPIV_40Transparent.JPG')
# BackG_BR = plt.imread(r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/Report/Images/Background_before_rain.JPG')
# BackG_TR = plt.imread(r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/Report/Images/Background_tracers.JPG')
#
# XY    = plt.imread(r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/LSPIV/Results/Velocity_vectors/OS.PNG')
# CM    = plt.imread(r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/LSPIV/Results/LSPIV_CM/OS.PNG')
# VE    = plt.imread(r'C:/Users/SSchurer/Documents/TU_Delft/Thesis/LSPIV/Results/Vector_fields2/OS.JPG')
#
#
# f = plt.figure(figsize=(20,5))
# # plt.title('OS')
# ax1=f.add_subplot(131, frameon=False)
# ax1.imshow(VE)
# ax1.axis('off')
# ax2=f.add_subplot(132, frameon=False)
# ax2.imshow(CM)
# ax2.axis('off')
# ax3=f.add_subplot(133, frameon=False)
# ax3.imshow(XY)
# ax3.axis('off');
#
# # plt.savefig('C:/Users/SSchurer/Documents/TU_Delft/Thesis/LSPIV/Results/OS.jpg')
